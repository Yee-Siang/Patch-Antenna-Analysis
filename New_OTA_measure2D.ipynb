# %%
tr_path = 'otatrain.csv'  # path to training data

# !gdown --id '1c9OkEgKqH0Fx57j37s03uoi4Q_CVYvir' --output otatrain.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1c9OkEgKqH0Fx57j37s03uoi4Q_CVYvir
# To: /content/otatrain.csv
# 2.68MB [00:00, 42.4MB/s]

# %% [markdown]
# # **Import Some Packages**

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# # **Some Utilities**
#
# You do not need to modify this part.

# %%
def random_seed_setup(seed):
    # For reproducibility
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        return 'cuda'
    else:
        return 'cpu'
'''
def plot_learning_curve(loss_record, title=''):
    #Plot learning curve of your DNN (train & dev loss) 
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()
'''

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 50.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()

# %%
class PatchOTA(Dataset):
    def __init__(self,
                 input_array,
                 mode='train',
                 normalize='none',
                 target_only=False,
                 norm_mean=None,
                 norm_std=None):
        self.mode = mode

      
        data = np.array(input_array[0:])[:, 0:].astype(float)
        
        if not target_only:
            feats = list(range(2))
        else:
            pass

        if mode == 'test':
            # Testing data
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training data (train/dev sets)
            target = data[:, 2:]
            data = data[:, feats]
            
            # Splitting training data into train & dev sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 50 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 50 == 0]
            else:
                indices = list(range(len(data)))
                # only when mode == 'train_all' (i.e., using all data for training)
            
            data = data[indices]
            target = target[indices]
            
            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data)
            self.target = torch.FloatTensor(target)
        
        self.norm_mean = None
        self.norm_std = None

        if normalize == 'self':
            self.norm_mean = self.data.mean(dim=0).unsqueeze(0)
            self.norm_std = self.data.std(dim=0).unsqueeze(0)
            self.data = (self.data - self.norm_mean) / self.norm_std

        if normalize == 'given' and (norm_mean is not None) and (norm_std is not None):
            self.data = (self.data - norm_mean) / norm_std

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of the Covid19 Dataset ({} samples found, each dim = {})'
              .format(mode, self.data.shape[0], self.data.shape[1]))

    def __getitem__(self, index):
        if self.mode in ['train', 'dev', 'train_all']:
            return self.data[index], self.target[index]
        else:
            return self.data[index]

    def __len__(self):
        return len(self.data)

# %% [markdown]
# ## **DataLoader**
#
# A `DataLoader` loads data from a given `Dataset` into batches.

# %%
def prep_dataloader(tr_path, tt_path, batch_size, n_jobs=0, target_only=False):
    tr_dataset = PatchOTA(
        tr_path, mode='train_all',
        normalize='self', 
        target_only=target_only)

    dv_dataset = PatchOTA(
        tr_path, mode='dev',
        normalize='given', 
        target_only=target_only,
        norm_mean=tr_dataset.norm_mean,
        norm_std=tr_dataset.norm_std)

    tt_dataset = PatchOTA(
        tt_path, mode='test',
        normalize='given',
        target_only=target_only,
        norm_mean=tr_dataset.norm_mean,
        norm_std=tr_dataset.norm_std)
    
    tr_dataloader = DataLoader(
        tr_dataset, batch_size,
        shuffle=True, drop_last=False,
        num_workers=n_jobs, pin_memory=True)
    
    dv_dataloader = DataLoader(
        dv_dataset, batch_size,
        shuffle=False, drop_last=False,
        num_workers=n_jobs, pin_memory=True)

    tt_dataloader = DataLoader(
        tt_dataset, batch_size,
        shuffle=False, drop_last=False,
        num_workers=n_jobs, pin_memory=True)
    
    return tr_dataloader, dv_dataloader, tt_dataloader

# %% [markdown]
# # **Deep Neural Network**
#
# `NeuralNet` is an `nn.Module` designed for regression.
# The DNN consists of 2 fully-connected layers with ReLU activation.
# This module also included a function `cal_loss` for calculating loss.

# %%
class NeuralNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self, input_dim, l2_reg=0.):
        super(NeuralNet, self).__init__()

        # Define your neural network here
        self.net = nn.Sequential(
            nn.Linear(input_dim, 91),
            nn.RReLU(),  # randomized ReLU
            nn.Linear(91, 25)
        )

        # Mean squared error loss
        self.criterion = nn.MSELoss(reduction='mean')
        self.l2_reg = l2_reg

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target, is_train=True):
        ''' Calculate loss '''
        total_loss = 0

        mse_loss = self.criterion(pred, target)
        total_loss += mse_loss
        if is_train and self.l2_reg > 0.:
            reg_loss = 0
            for param in self.parameters():
                reg_loss += torch.norm(param, p=2)
            total_loss += reg_loss * self.l2_reg
        
        return total_loss, mse_loss

# %% [markdown]
# # **Train/Dev/Test**

# %% [markdown]
# ## **Training**

# %%
def train(tr_set, dv_set, model, config, device):
    n_epochs = config['n_epochs']
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    loss_record = {'train': [], 'dev': []}
    min_mse = 1000.
    epoch = 0
    while epoch < n_epochs:
        model.train()
        for i, (x, y) in enumerate(tr_set):
            optimizer.zero_grad()
            x, y = x.to(device), y.to(device)
            pred = model(x)
            total_loss, mse_loss = model.cal_loss(pred, y, is_train=True)
            total_loss.backward()
            optimizer.step()
            loss_record['train'].append(total_loss.detach().cpu().item())

        dev_mse = dev(dv_set, model, device)

        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1
        
        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            # Stop training if your model stops improving for "config['early_stop']" epochs.
            break

    print('Finished training after {} epochs'.format(epoch))

    return min_mse, loss_record

def dev(dv_set, model, device):
    model.eval()
    total_loss = 0
    for x, y in dv_set:
        x, y = x.to(device), y.to(device)
        with torch.no_grad():
            pred = model(x)
            _, mse_loss = model.cal_loss(pred, y, is_train=False)
        total_loss += mse_loss.detach().cpu().item() * len(x)
    total_loss = total_loss / len(dv_set.dataset)
   # print('total_loss =', total_loss)
    return total_loss

# %% [markdown]
# ## **Testing**

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds[0]

# %% [markdown]
# # **Setup Hyper-parameters**
#
# `config` contains hyper-parameters for training and the path to save your model.

# %%
device = random_seed_setup(42097)
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
target_only = False

config = {
    'n_epochs': 10000,                  # maximum number of epochs
    'batch_size': 20,               # mini-batch size for dataloader
    'optimizer': 'SGD',              # optimization algorithm (optimizer in torch.optim)
    'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
        'lr': 0.001,                 # learning rate of SGD
        'momentum': 0.9              # momentum for SGD
    },
    'early_stop': 200,                # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %%
with open('otatrain.csv', 'r') as fp:
    data = list(csv.reader(fp))
    horizontal_data = np.array(data[2:4516])[:, 2:]
    vertical_data = np.array(data[4518:9032])[:, 2:]
    total_data = np.array(data[9034:13548])[:, 2:]

# %%
horizontal_dataset = []
for j in range(301):
    for k in range(13):
        ls = []
        ls.append(4000+10*j)
        for element in horizontal_data[1+15*j+k][0:]:
            ls.append(float(element))
        horizontal_dataset.append(ls)

vertical_dataset = []
for j in range(301):
    for k in range(13):
        ls = []
        ls.append(4000+10*j)
        for element in vertical_data[1+15*j+k][0:]:
            ls.append(float(element))
        vertical_dataset.append(ls)

total_dataset = []
for j in range(301):
    for k in range(13):
        ls = []
        ls.append(4000+10*j)
        for element in total_data[1+15*j+k][0:]:
            ls.append(float(element))
        total_dataset.append(ls)

# %%
horizontal_test = []
horizontal_test.append([4007.5,8.5])
for ele in horizontal_dataset:
    horizontal_test.append(ele[0:2])

# %% [markdown]
# # **Load data and model**

# %%
tr_set, dv_set, tt_set = prep_dataloader(
    horizontal_dataset, horizontal_test, config['batch_size'], 
    target_only=target_only)
# Out:
# Finished reading the train_all set of the Covid19 Dataset (3913 samples found, each dim = 2)
# Finished reading the dev set of the Covid19 Dataset (79 samples found, each dim = 2)
# Finished reading the test set of the Covid19 Dataset (3914 samples found, each dim = 2)

# %%
model = NeuralNet(tr_set.dataset.dim, 0.001).to(device)  # Construct model and move to device

# %% [markdown]
# # **Start Training!**

# %%
model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 25.0758)
# Saving model (epoch =    2, loss = 22.1844)
# Saving model (epoch =    3, loss = 19.9729)
# Saving model (epoch =    4, loss = 18.5105)
# Saving model (epoch =    5, loss = 17.3763)
# Saving model (epoch =    6, loss = 16.5914)
# Saving model (epoch =    7, loss = 16.0129)
# Saving model (epoch =    8, loss = 15.6954)
# Saving model (epoch =    9, loss = 15.3743)
# Saving model (epoch =   10, loss = 15.1943)
# Saving model (epoch =   11, loss = 14.9672)
# Saving model (epoch =   12, loss = 14.9137)
# Saving model (epoch =   13, loss = 14.7164)
# Saving model (epoch =   14, loss = 14.6752)
# Saving model (epoch =   15, loss = 14.5488)
# Saving model (epoch =   16, loss = 14.3814)
# Saving model (epoch =   18, loss = 14.2920)
# Saving model (epoch =   19, loss = 14.0760)
# Saving model (epoch =   20, loss = 14.0168)
# Saving model (epoch =   21, loss = 13.9360)
# Saving model (epoch =   22, loss = 13.8103)
# Saving model (epoch =   23, loss = 13.7075)
# Saving model (epoch =   24, loss = 13.5624)
# Saving model (epoch =   26, loss = 13.2513)
# Saving model (epoch =   28, loss = 13.1009)
# Saving model (epoch =   29, loss = 12.9881)
# Saving model (epoch =   30, loss = 12.7857)
# Saving model (epoch =   31, loss = 12.7141)
# Saving model (epoch =   32, loss = 12.6157)
# Saving model (epoch =   33, loss = 12.4503)
# Saving model (epoch =   34, loss = 12.4447)
# Saving model (epoch =   35, loss = 12.2597)
# Saving model (epoch =   36, loss = 12.1090)
# Saving model (epoch =   37, loss = 12.0384)
# Saving model (epoch =   38, loss = 11.8751)
# Saving model (epoch =   39, loss = 11.8262)
# Saving model (epoch =   40, loss = 11.7913)
# Saving model (epoch =   41, loss = 11.6541)
# Saving model (epoch =   42, loss = 11.5701)
# Saving model (epoch =   43, loss = 11.4478)
# Saving model (epoch =   45, loss = 11.3044)
# Saving model (epoch =   46, loss = 11.2866)
# Saving model (epoch =   47, loss = 11.2390)
# Saving model (epoch =   48, loss = 11.1386)
# Saving model (epoch =   49, loss = 11.1368)
# Saving model (epoch =   51, loss = 10.9513)
# Saving model (epoch =   52, loss = 10.9314)
# Saving model (epoch =   53, loss = 10.9061)
# Saving model (epoch =   54, loss = 10.7777)
# Saving model (epoch =   55, loss = 10.7687)
# Saving model (epoch =   57, loss = 10.7280)
# Saving model (epoch =   60, loss = 10.6719)
# Saving model (epoch =   61, loss = 10.5751)
# Saving model (epoch =   62, loss = 10.5616)
# Saving model (epoch =   63, loss = 10.5273)
# Saving model (epoch =   64, loss = 10.4837)
# Saving model (epoch =   66, loss = 10.4101)
# Saving model (epoch =   69, loss = 10.3465)
# Saving model (epoch =   71, loss = 10.3422)
# Saving model (epoch =   74, loss = 10.2352)
# Saving model (epoch =   77, loss = 10.1888)
# Saving model (epoch =   78, loss = 10.1178)
# Saving model (epoch =   81, loss = 10.0801)
# Saving model (epoch =   83, loss = 10.0183)
# Saving model (epoch =   85, loss = 9.9907)
# Saving model (epoch =   87, loss = 9.9745)
# Saving model (epoch =   94, loss = 9.8990)
# Saving model (epoch =   97, loss = 9.8838)
# Saving model (epoch =   98, loss = 9.8335)
# Saving model (epoch =   99, loss = 9.8086)
# Saving model (epoch =  100, loss = 9.7983)
# Saving model (epoch =  105, loss = 9.7307)
# Saving model (epoch =  106, loss = 9.7170)
# Saving model (epoch =  107, loss = 9.6232)
# Saving model (epoch =  116, loss = 9.6102)
# Saving model (epoch =  117, loss = 9.5557)
# Saving model (epoch =  120, loss = 9.5351)
# Saving model (epoch =  122, loss = 9.4370)
# Saving model (epoch =  126, loss = 9.4362)
# Saving model (epoch =  129, loss = 9.4184)
# Saving model (epoch =  133, loss = 9.3932)
# Saving model (epoch =  135, loss = 9.3925)
# Saving model (epoch =  136, loss = 9.3642)
# Saving model (epoch =  139, loss = 9.3424)
# Saving model (epoch =  144, loss = 9.2427)
# Saving model (epoch =  149, loss = 9.2202)
# Saving model (epoch =  150, loss = 9.2149)
# Saving model (epoch =  153, loss = 9.1120)
# Saving model (epoch =  161, loss = 9.0693)
# Saving model (epoch =  166, loss = 9.0275)
# Saving model (epoch =  174, loss = 9.0101)
# Saving model (epoch =  176, loss = 8.9917)
# Saving model (epoch =  181, loss = 8.9631)
# Saving model (epoch =  182, loss = 8.9128)
# Saving model (epoch =  188, loss = 8.8896)
# Saving model (epoch =  194, loss = 8.8817)
# Saving model (epoch =  197, loss = 8.8557)
# Saving model (epoch =  199, loss = 8.8484)
# Saving model (epoch =  202, loss = 8.8473)
# Saving model (epoch =  204, loss = 8.8161)
# Saving model (epoch =  207, loss = 8.7848)
# Saving model (epoch =  210, loss = 8.7413)
# Saving model (epoch =  223, loss = 8.6595)
# Saving model (epoch =  228, loss = 8.6523)
# Saving model (epoch =  232, loss = 8.6320)
# Saving model (epoch =  242, loss = 8.6070)
# Saving model (epoch =  245, loss = 8.5509)
# Saving model (epoch =  263, loss = 8.4584)
# Saving model (epoch =  277, loss = 8.4500)
# Saving model (epoch =  280, loss = 8.4494)
# Saving model (epoch =  282, loss = 8.4355)
# Saving model (epoch =  294, loss = 8.4051)
# Saving model (epoch =  300, loss = 8.3647)
# Saving model (epoch =  302, loss = 8.3604)
# Saving model (epoch =  304, loss = 8.3154)
# Saving model (epoch =  310, loss = 8.2915)
# Saving model (epoch =  312, loss = 8.2729)
# Saving model (epoch =  324, loss = 8.2458)
# Saving model (epoch =  329, loss = 8.1933)
# Saving model (epoch =  349, loss = 8.1832)
# Saving model (epoch =  351, loss = 8.1781)
# Saving model (epoch =  363, loss = 8.1634)
# Saving model (epoch =  365, loss = 8.1050)
# Saving model (epoch =  374, loss = 8.0789)
# Saving model (epoch =  419, loss = 8.0364)
# Saving model (epoch =  420, loss = 8.0078)
# Saving model (epoch =  424, loss = 7.9838)
# Saving model (epoch =  436, loss = 7.9699)
# Saving model (epoch =  458, loss = 7.9695)
# Saving model (epoch =  464, loss = 7.9088)
# Saving model (epoch =  470, loss = 7.9010)
# Saving model (epoch =  480, loss = 7.8899)
# Saving model (epoch =  484, loss = 7.8835)
# Saving model (epoch =  485, loss = 7.8786)
# Saving model (epoch =  495, loss = 7.8652)
# Saving model (epoch =  497, loss = 7.8159)
# Saving model (epoch =  513, loss = 7.8151)
# Saving model (epoch =  515, loss = 7.7588)
# Saving model (epoch =  546, loss = 7.7462)
# Saving model (epoch =  547, loss = 7.6849)
# Saving model (epoch =  588, loss = 7.6680)
# Saving model (epoch =  608, loss = 7.6287)
# Saving model (epoch =  613, loss = 7.6263)
# Saving model (epoch =  633, loss = 7.5989)
# Saving model (epoch =  637, loss = 7.5587)
# Saving model (epoch =  643, loss = 7.5578)
# Saving model (epoch =  647, loss = 7.5469)
# Saving model (epoch =  660, loss = 7.4952)
# Saving model (epoch =  676, loss = 7.4662)
# Saving model (epoch =  683, loss = 7.4634)
# Saving model (epoch =  688, loss = 7.4597)
# Saving model (epoch =  693, loss = 7.4571)
# Saving model (epoch =  707, loss = 7.4521)
# Saving model (epoch =  721, loss = 7.4076)
# Saving model (epoch =  725, loss = 7.3474)
# Saving model (epoch =  752, loss = 7.2848)
# Saving model (epoch =  812, loss = 7.2830)
# Saving model (epoch =  821, loss = 7.2482)
# Saving model (epoch =  823, loss = 7.2209)
# Saving model (epoch =  840, loss = 7.1863)
# Saving model (epoch =  842, loss = 7.1755)
# Saving model (epoch =  864, loss = 7.1332)
# Saving model (epoch =  890, loss = 7.1297)
# Saving model (epoch =  900, loss = 7.1273)
# Saving model (epoch =  912, loss = 7.0802)
# Saving model (epoch =  934, loss = 7.0339)
# Saving model (epoch =  973, loss = 7.0313)
# Saving model (epoch =  986, loss = 7.0067)
# Saving model (epoch =  995, loss = 6.8732)
# Saving model (epoch = 1157, loss = 6.8571)
# Saving model (epoch = 1188, loss = 6.8198)
# Saving model (epoch = 1192, loss = 6.8090)
# Saving model (epoch = 1244, loss = 6.8045)
# Saving model (epoch = 1255, loss = 6.7947)
# Saving model (epoch = 1259, loss = 6.7789)
# Saving model (epoch = 1276, loss = 6.7370)
# Saving model (epoch = 1412, loss = 6.6843)
# Saving model (epoch = 1461, loss = 6.6728)
# Saving model (epoch = 1519, loss = 6.6498)
# Saving model (epoch = 1570, loss = 6.6200)
# Saving model (epoch = 1635, loss = 6.6164)
# Saving model (epoch = 1759, loss = 6.5926)
# Saving model (epoch = 1798, loss = 6.5795)
# Saving model (epoch = 1832, loss = 6.5621)
# Saving model (epoch = 1851, loss = 6.5563)
# Saving model (epoch = 1856, loss = 6.5290)
# Saving model (epoch = 1911, loss = 6.5165)
# Saving model (epoch = 2024, loss = 6.4955)
# Saving model (epoch = 2048, loss = 6.4885)
# Saving model (epoch = 2063, loss = 6.4557)
# Saving model (epoch = 2184, loss = 6.4440)
# Saving model (epoch = 2300, loss = 6.4312)
# Saving model (epoch = 2402, loss = 6.4271)
# Saving model (epoch = 2549, loss = 6.4039)
# Saving model (epoch = 2555, loss = 6.3991)
# Saving model (epoch = 2579, loss = 6.3944)
# Saving model (epoch = 2667, loss = 6.3705)
# Saving model (epoch = 2848, loss = 6.3343)
# Saving model (epoch = 2857, loss = 6.2841)
# Finished training after 3058 epochs

# %%
plot_learning_curve(model_loss_record[1], title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
# Out:
# <All keys matched successfully>

# %%
 prediction = test(tt_set, model, device)

# %%
prediction
# Out:
# array([-16.482067, -15.82944 , -17.499752, -18.194996, -20.177834,
#        -22.054968, -26.131437, -30.900627, -25.807747, -21.79853 ,
#        -20.220394, -18.11305 , -16.888123, -17.784452, -17.1544  ,
#        -18.564577, -21.1108  , -24.633991, -28.482769, -33.716404,
#        -26.428297, -21.030073, -18.705435, -17.339794, -16.476482],
#       dtype=float32)

# %%
labels = np.array([str(15*j) for j in range(25)])
#資料個數
dataLenth = 25
#資料
data = np.array(prediction)

angles = np.linspace(0, 2*np.pi, dataLenth, endpoint=False)
data = np.concatenate((data, [data[0]])) # 閉合 # #將資料結合起來
angles = np.concatenate((angles, [angles[0]])) # 閉合

fig = plt.figure()
ax = fig.add_subplot(121, polar=True)# polar引數！！代表畫圓形！！！！
#111代表總行數總列數位置
ax.plot(angles, data, 'r', linewidth=1, markersize=0)# 畫線四個引數為x,y,標記和顏色，閒的寬度
ax.fill(angles, data, facecolor='r', alpha=0)# 填充顏色和透明度
ax.set_thetagrids(angles * 180/np.pi, labels, fontproperties="SimHei")
#ax.set_title("H dB",fontsize = 80, fontproperties="SimHei")
ax.set_rlim(-40,-10)
ax.grid(True)
plt.show()

# %%
vertical_test = []
vertical_test.append([4007.5,8.5])
for ele in vertical_dataset:
    vertical_test.append(ele[0:2])

# %%
tr_set, dv_set, tt_set = prep_dataloader(
    vertical_dataset, vertical_test, config['batch_size'], 
    target_only=target_only)
# Out:
# Finished reading the train_all set of the Covid19 Dataset (3913 samples found, each dim = 2)
# Finished reading the dev set of the Covid19 Dataset (79 samples found, each dim = 2)
# Finished reading the test set of the Covid19 Dataset (3914 samples found, each dim = 2)

# %%
model = NeuralNet(tr_set.dataset.dim, 0.001).to(device)  # Construct model and move to device

# %%
model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 31.3954)
# Saving model (epoch =    2, loss = 28.7487)
# Saving model (epoch =    3, loss = 27.2316)
# Saving model (epoch =    4, loss = 26.4317)
# Saving model (epoch =    5, loss = 25.4922)
# Saving model (epoch =    6, loss = 24.6340)
# Saving model (epoch =    7, loss = 23.7756)
# Saving model (epoch =    8, loss = 22.9608)
# Saving model (epoch =    9, loss = 22.2017)
# Saving model (epoch =   10, loss = 21.6798)
# Saving model (epoch =   11, loss = 21.6133)
# Saving model (epoch =   12, loss = 20.9089)
# Saving model (epoch =   13, loss = 20.8504)
# Saving model (epoch =   14, loss = 20.5195)
# Saving model (epoch =   15, loss = 20.2331)
# Saving model (epoch =   17, loss = 19.9691)
# Saving model (epoch =   18, loss = 19.8746)
# Saving model (epoch =   20, loss = 19.4473)
# Saving model (epoch =   21, loss = 19.3747)
# Saving model (epoch =   22, loss = 19.1399)
# Saving model (epoch =   23, loss = 18.9913)
# Saving model (epoch =   25, loss = 18.8119)
# Saving model (epoch =   26, loss = 18.7023)
# Saving model (epoch =   27, loss = 18.4196)
# Saving model (epoch =   28, loss = 18.3718)
# Saving model (epoch =   29, loss = 18.0841)
# Saving model (epoch =   30, loss = 18.0822)
# Saving model (epoch =   31, loss = 17.8571)
# Saving model (epoch =   32, loss = 17.8177)
# Saving model (epoch =   34, loss = 17.4849)
# Saving model (epoch =   35, loss = 17.4702)
# Saving model (epoch =   36, loss = 17.1970)
# Saving model (epoch =   37, loss = 17.0290)
# Saving model (epoch =   38, loss = 17.0288)
# Saving model (epoch =   39, loss = 16.7863)
# Saving model (epoch =   40, loss = 16.7786)
# Saving model (epoch =   41, loss = 16.5665)
# Saving model (epoch =   42, loss = 16.5454)
# Saving model (epoch =   44, loss = 16.2909)
# Saving model (epoch =   45, loss = 16.1884)
# Saving model (epoch =   46, loss = 16.0948)
# Saving model (epoch =   47, loss = 15.9974)
# Saving model (epoch =   49, loss = 15.8239)
# Saving model (epoch =   50, loss = 15.5898)
# Saving model (epoch =   52, loss = 15.4850)
# Saving model (epoch =   54, loss = 15.4467)
# Saving model (epoch =   55, loss = 15.2200)
# Saving model (epoch =   57, loss = 15.1306)
# Saving model (epoch =   58, loss = 14.8849)
# Saving model (epoch =   59, loss = 14.8023)
# Saving model (epoch =   61, loss = 14.7154)
# Saving model (epoch =   62, loss = 14.5609)
# Saving model (epoch =   64, loss = 14.4392)
# Saving model (epoch =   67, loss = 14.1901)
# Saving model (epoch =   71, loss = 14.0734)
# Saving model (epoch =   73, loss = 13.9510)
# Saving model (epoch =   74, loss = 13.8399)
# Saving model (epoch =   76, loss = 13.8259)
# Saving model (epoch =   78, loss = 13.5990)
# Saving model (epoch =   79, loss = 13.5845)
# Saving model (epoch =   81, loss = 13.4616)
# Saving model (epoch =   82, loss = 13.3298)
# Saving model (epoch =   83, loss = 13.3213)
# Saving model (epoch =   85, loss = 13.3081)
# Saving model (epoch =   87, loss = 13.2802)
# Saving model (epoch =   88, loss = 13.2310)
# Saving model (epoch =   89, loss = 13.0768)
# Saving model (epoch =   91, loss = 12.9743)
# Saving model (epoch =   93, loss = 12.9223)
# Saving model (epoch =   97, loss = 12.8998)
# Saving model (epoch =   98, loss = 12.7667)
# Saving model (epoch =   99, loss = 12.7131)
# Saving model (epoch =  100, loss = 12.6775)
# Saving model (epoch =  104, loss = 12.6549)
# Saving model (epoch =  106, loss = 12.5319)
# Saving model (epoch =  109, loss = 12.4621)
# Saving model (epoch =  110, loss = 12.3680)
# Saving model (epoch =  114, loss = 12.2526)
# Saving model (epoch =  115, loss = 12.2525)
# Saving model (epoch =  119, loss = 12.1606)
# Saving model (epoch =  120, loss = 12.1133)
# Saving model (epoch =  121, loss = 12.0390)
# Saving model (epoch =  122, loss = 12.0005)
# Saving model (epoch =  123, loss = 11.9613)
# Saving model (epoch =  126, loss = 11.9291)
# Saving model (epoch =  132, loss = 11.7941)
# Saving model (epoch =  134, loss = 11.7295)
# Saving model (epoch =  135, loss = 11.6924)
# Saving model (epoch =  143, loss = 11.5057)
# Saving model (epoch =  151, loss = 11.3457)
# Saving model (epoch =  155, loss = 11.3205)
# Saving model (epoch =  158, loss = 11.2981)
# Saving model (epoch =  162, loss = 11.1303)
# Saving model (epoch =  166, loss = 11.1048)
# Saving model (epoch =  170, loss = 11.0753)
# Saving model (epoch =  181, loss = 10.9837)
# Saving model (epoch =  182, loss = 10.9282)
# Saving model (epoch =  184, loss = 10.8753)
# Saving model (epoch =  185, loss = 10.8701)
# Saving model (epoch =  187, loss = 10.8115)
# Saving model (epoch =  190, loss = 10.8081)
# Saving model (epoch =  191, loss = 10.7648)
# Saving model (epoch =  197, loss = 10.6760)
# Saving model (epoch =  200, loss = 10.6599)
# Saving model (epoch =  205, loss = 10.6177)
# Saving model (epoch =  206, loss = 10.5819)
# Saving model (epoch =  209, loss = 10.5177)
# Saving model (epoch =  214, loss = 10.4605)
# Saving model (epoch =  224, loss = 10.3691)
# Saving model (epoch =  226, loss = 10.3569)
# Saving model (epoch =  230, loss = 10.3157)
# Saving model (epoch =  232, loss = 10.3118)
# Saving model (epoch =  235, loss = 10.1836)
# Saving model (epoch =  246, loss = 10.1590)
# Saving model (epoch =  249, loss = 10.1138)
# Saving model (epoch =  255, loss = 10.0750)
# Saving model (epoch =  256, loss = 10.0567)
# Saving model (epoch =  257, loss = 9.9680)
# Saving model (epoch =  266, loss = 9.9283)
# Saving model (epoch =  276, loss = 9.8890)
# Saving model (epoch =  286, loss = 9.8227)
# Saving model (epoch =  299, loss = 9.8008)
# Saving model (epoch =  304, loss = 9.7865)
# Saving model (epoch =  306, loss = 9.7765)
# Saving model (epoch =  309, loss = 9.7533)
# Saving model (epoch =  310, loss = 9.7487)
# Saving model (epoch =  315, loss = 9.6142)
# Saving model (epoch =  330, loss = 9.6132)
# Saving model (epoch =  341, loss = 9.5942)
# Saving model (epoch =  344, loss = 9.5647)
# Saving model (epoch =  352, loss = 9.5345)
# Saving model (epoch =  355, loss = 9.4197)
# Saving model (epoch =  370, loss = 9.3297)
# Saving model (epoch =  382, loss = 9.2421)
# Saving model (epoch =  425, loss = 9.1594)
# Saving model (epoch =  430, loss = 9.1333)
# Saving model (epoch =  446, loss = 9.0316)
# Saving model (epoch =  495, loss = 8.9678)
# Saving model (epoch =  498, loss = 8.9538)
# Saving model (epoch =  519, loss = 8.9499)
# Saving model (epoch =  541, loss = 8.9391)
# Saving model (epoch =  563, loss = 8.9304)
# Saving model (epoch =  569, loss = 8.8674)
# Saving model (epoch =  575, loss = 8.8537)
# Saving model (epoch =  584, loss = 8.8027)
# Saving model (epoch =  644, loss = 8.7722)
# Saving model (epoch =  672, loss = 8.7284)
# Saving model (epoch =  700, loss = 8.7219)
# Saving model (epoch =  704, loss = 8.6863)
# Saving model (epoch =  723, loss = 8.5746)
# Saving model (epoch =  827, loss = 8.5641)
# Saving model (epoch =  858, loss = 8.5569)
# Saving model (epoch =  873, loss = 8.4517)
# Saving model (epoch =  946, loss = 8.4437)
# Saving model (epoch = 1004, loss = 8.3791)
# Saving model (epoch = 1058, loss = 8.3334)
# Saving model (epoch = 1231, loss = 8.3217)
# Saving model (epoch = 1310, loss = 8.2912)
# Saving model (epoch = 1347, loss = 8.2286)
# Saving model (epoch = 1458, loss = 8.2020)
# Saving model (epoch = 1494, loss = 8.1735)
# Saving model (epoch = 1538, loss = 8.1708)
# Saving model (epoch = 1545, loss = 8.1398)
# Saving model (epoch = 1663, loss = 8.0697)
# Saving model (epoch = 1665, loss = 8.0229)
# Finished training after 1866 epochs

# %%
plot_learning_curve(model_loss_record[1], title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
# Out:
# <All keys matched successfully>

# %%
prediction = test(tt_set, model, device)

# %%
labels = np.array([str(15*j) for j in range(25)])
#資料個數
dataLenth = 25
#資料
data = np.array(prediction)

angles = np.linspace(0, 2*np.pi, dataLenth, endpoint=False)
data = np.concatenate((data, [data[0]])) # 閉合 # #將資料結合起來
angles = np.concatenate((angles, [angles[0]])) # 閉合

fig = plt.figure()
ax = fig.add_subplot(121, polar=True)# polar引數！！代表畫圓形！！！！
#111代表總行數總列數位置
ax.plot(angles, data, 'b', linewidth=1, markersize=0)# 畫線四個引數為x,y,標記和顏色，閒的寬度
ax.fill(angles, data, facecolor='r', alpha=0)# 填充顏色和透明度
ax.set_thetagrids(angles * 180/np.pi, labels, fontproperties="SimHei")
#ax.set_title("H dB",fontsize = 80, fontproperties="SimHei")
ax.set_rlim(-40,-10)
ax.grid(True)
plt.show()

# %%
total_test = []
total_test.append([4007.5,8.5])
for ele in total_dataset:
    total_test.append(ele[0:2])

# %%
tr_set, dv_set, tt_set = prep_dataloader(
    total_dataset, total_test, config['batch_size'], 
    target_only=target_only)
# Out:
# Finished reading the train_all set of the Covid19 Dataset (3913 samples found, each dim = 2)
# Finished reading the dev set of the Covid19 Dataset (79 samples found, each dim = 2)
# Finished reading the test set of the Covid19 Dataset (3914 samples found, each dim = 2)

# %%
model = NeuralNet(tr_set.dataset.dim, 0.001).to(device)  # Construct model and move to device

# %%
model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 15.4641)
# Saving model (epoch =    2, loss = 12.6762)
# Saving model (epoch =    3, loss = 11.1751)
# Saving model (epoch =    4, loss = 10.5666)
# Saving model (epoch =    5, loss = 10.1442)
# Saving model (epoch =    6, loss = 9.9929)
# Saving model (epoch =    7, loss = 9.8355)
# Saving model (epoch =    8, loss = 9.7470)
# Saving model (epoch =    9, loss = 9.6833)
# Saving model (epoch =   10, loss = 9.5204)
# Saving model (epoch =   11, loss = 9.3980)
# Saving model (epoch =   14, loss = 9.2250)
# Saving model (epoch =   15, loss = 9.1922)
# Saving model (epoch =   16, loss = 9.0766)
# Saving model (epoch =   17, loss = 9.0148)
# Saving model (epoch =   18, loss = 8.9344)
# Saving model (epoch =   19, loss = 8.8711)
# Saving model (epoch =   20, loss = 8.7571)
# Saving model (epoch =   21, loss = 8.6805)
# Saving model (epoch =   22, loss = 8.6115)
# Saving model (epoch =   23, loss = 8.5111)
# Saving model (epoch =   24, loss = 8.4087)
# Saving model (epoch =   25, loss = 8.3148)
# Saving model (epoch =   26, loss = 8.2515)
# Saving model (epoch =   27, loss = 8.0747)
# Saving model (epoch =   28, loss = 7.9882)
# Saving model (epoch =   29, loss = 7.9284)
# Saving model (epoch =   30, loss = 7.8758)
# Saving model (epoch =   31, loss = 7.7855)
# Saving model (epoch =   32, loss = 7.5704)
# Saving model (epoch =   33, loss = 7.4596)
# Saving model (epoch =   34, loss = 7.3974)
# Saving model (epoch =   35, loss = 7.2637)
# Saving model (epoch =   36, loss = 7.2463)
# Saving model (epoch =   37, loss = 7.1779)
# Saving model (epoch =   38, loss = 6.9404)
# Saving model (epoch =   39, loss = 6.8799)
# Saving model (epoch =   40, loss = 6.7140)
# Saving model (epoch =   41, loss = 6.6908)
# Saving model (epoch =   42, loss = 6.5583)
# Saving model (epoch =   43, loss = 6.5044)
# Saving model (epoch =   44, loss = 6.3994)
# Saving model (epoch =   46, loss = 6.2962)
# Saving model (epoch =   48, loss = 6.1214)
# Saving model (epoch =   49, loss = 6.0461)
# Saving model (epoch =   50, loss = 5.9739)
# Saving model (epoch =   51, loss = 5.8848)
# Saving model (epoch =   53, loss = 5.8435)
# Saving model (epoch =   54, loss = 5.7343)
# Saving model (epoch =   55, loss = 5.6820)
# Saving model (epoch =   56, loss = 5.6610)
# Saving model (epoch =   57, loss = 5.6269)
# Saving model (epoch =   58, loss = 5.5947)
# Saving model (epoch =   59, loss = 5.5916)
# Saving model (epoch =   60, loss = 5.4730)
# Saving model (epoch =   61, loss = 5.4462)
# Saving model (epoch =   62, loss = 5.4306)
# Saving model (epoch =   63, loss = 5.3697)
# Saving model (epoch =   65, loss = 5.3647)
# Saving model (epoch =   66, loss = 5.3471)
# Saving model (epoch =   68, loss = 5.2945)
# Saving model (epoch =   69, loss = 5.2297)
# Saving model (epoch =   70, loss = 5.1994)
# Saving model (epoch =   74, loss = 5.1682)
# Saving model (epoch =   75, loss = 5.1469)
# Saving model (epoch =   77, loss = 5.1417)
# Saving model (epoch =   79, loss = 5.0543)
# Saving model (epoch =   82, loss = 5.0288)
# Saving model (epoch =   85, loss = 4.9790)
# Saving model (epoch =   91, loss = 4.9193)
# Saving model (epoch =   92, loss = 4.9164)
# Saving model (epoch =   96, loss = 4.8816)
# Saving model (epoch =   99, loss = 4.8738)
# Saving model (epoch =  102, loss = 4.8657)
# Saving model (epoch =  105, loss = 4.8035)
# Saving model (epoch =  106, loss = 4.8017)
# Saving model (epoch =  108, loss = 4.7786)
# Saving model (epoch =  117, loss = 4.7120)
# Saving model (epoch =  119, loss = 4.6948)
# Saving model (epoch =  123, loss = 4.6643)
# Saving model (epoch =  126, loss = 4.6303)
# Saving model (epoch =  136, loss = 4.6112)
# Saving model (epoch =  139, loss = 4.5723)
# Saving model (epoch =  141, loss = 4.5376)
# Saving model (epoch =  148, loss = 4.4706)
# Saving model (epoch =  159, loss = 4.4528)
# Saving model (epoch =  162, loss = 4.4042)
# Saving model (epoch =  169, loss = 4.3815)
# Saving model (epoch =  174, loss = 4.3742)
# Saving model (epoch =  177, loss = 4.3657)
# Saving model (epoch =  179, loss = 4.3294)
# Saving model (epoch =  180, loss = 4.3150)
# Saving model (epoch =  182, loss = 4.2881)
# Saving model (epoch =  191, loss = 4.2574)
# Saving model (epoch =  195, loss = 4.2474)
# Saving model (epoch =  201, loss = 4.2408)
# Saving model (epoch =  204, loss = 4.2003)
# Saving model (epoch =  216, loss = 4.1852)
# Saving model (epoch =  217, loss = 4.1666)
# Saving model (epoch =  225, loss = 4.1450)
# Saving model (epoch =  234, loss = 4.1402)
# Saving model (epoch =  239, loss = 4.0930)
# Saving model (epoch =  253, loss = 4.0873)
# Saving model (epoch =  256, loss = 4.0493)
# Saving model (epoch =  266, loss = 4.0398)
# Saving model (epoch =  278, loss = 4.0241)
# Saving model (epoch =  284, loss = 4.0187)
# Saving model (epoch =  287, loss = 4.0186)
# Saving model (epoch =  288, loss = 4.0055)
# Saving model (epoch =  289, loss = 3.9979)
# Saving model (epoch =  292, loss = 3.9972)
# Saving model (epoch =  299, loss = 3.9943)
# Saving model (epoch =  302, loss = 3.9923)
# Saving model (epoch =  310, loss = 3.9636)
# Saving model (epoch =  311, loss = 3.9597)
# Saving model (epoch =  312, loss = 3.9380)
# Saving model (epoch =  319, loss = 3.9286)
# Saving model (epoch =  338, loss = 3.9195)
# Saving model (epoch =  339, loss = 3.8858)
# Saving model (epoch =  341, loss = 3.8673)
# Saving model (epoch =  350, loss = 3.8381)
# Saving model (epoch =  354, loss = 3.8263)
# Saving model (epoch =  356, loss = 3.8246)
# Saving model (epoch =  359, loss = 3.8077)
# Saving model (epoch =  362, loss = 3.7994)
# Saving model (epoch =  369, loss = 3.7811)
# Saving model (epoch =  389, loss = 3.7426)
# Saving model (epoch =  392, loss = 3.7325)
# Saving model (epoch =  398, loss = 3.7219)
# Saving model (epoch =  399, loss = 3.7205)
# Saving model (epoch =  402, loss = 3.7096)
# Saving model (epoch =  406, loss = 3.6864)
# Saving model (epoch =  410, loss = 3.6856)
# Saving model (epoch =  419, loss = 3.6822)
# Saving model (epoch =  427, loss = 3.6260)
# Saving model (epoch =  444, loss = 3.6097)
# Saving model (epoch =  448, loss = 3.5927)
# Saving model (epoch =  458, loss = 3.5797)
# Saving model (epoch =  460, loss = 3.5676)
# Saving model (epoch =  461, loss = 3.5570)
# Saving model (epoch =  467, loss = 3.5555)
# Saving model (epoch =  476, loss = 3.5244)
# Saving model (epoch =  493, loss = 3.5185)
# Saving model (epoch =  494, loss = 3.4867)
# Saving model (epoch =  515, loss = 3.4854)
# Saving model (epoch =  516, loss = 3.4802)
# Saving model (epoch =  519, loss = 3.4479)
# Saving model (epoch =  532, loss = 3.4425)
# Saving model (epoch =  539, loss = 3.4192)
# Saving model (epoch =  542, loss = 3.4145)
# Saving model (epoch =  558, loss = 3.3936)
# Saving model (epoch =  574, loss = 3.3575)
# Saving model (epoch =  577, loss = 3.3377)
# Saving model (epoch =  613, loss = 3.3243)
# Saving model (epoch =  614, loss = 3.2798)
# Saving model (epoch =  637, loss = 3.2785)
# Saving model (epoch =  638, loss = 3.2747)
# Saving model (epoch =  660, loss = 3.2568)
# Saving model (epoch =  691, loss = 3.2540)
# Saving model (epoch =  695, loss = 3.2196)
# Saving model (epoch =  748, loss = 3.2024)
# Saving model (epoch =  769, loss = 3.1787)
# Saving model (epoch =  791, loss = 3.1540)
# Saving model (epoch =  806, loss = 3.1469)
# Saving model (epoch =  829, loss = 3.1414)
# Saving model (epoch =  864, loss = 3.1354)
# Saving model (epoch =  869, loss = 3.0975)
# Saving model (epoch =  875, loss = 3.0601)
# Saving model (epoch =  917, loss = 3.0596)
# Saving model (epoch =  968, loss = 3.0345)
# Saving model (epoch =  993, loss = 3.0206)
# Saving model (epoch = 1000, loss = 3.0180)
# Saving model (epoch = 1011, loss = 3.0003)
# Saving model (epoch = 1032, loss = 2.9878)
# Saving model (epoch = 1034, loss = 2.9795)
# Saving model (epoch = 1069, loss = 2.9588)
# Saving model (epoch = 1112, loss = 2.9123)
# Saving model (epoch = 1134, loss = 2.8962)
# Saving model (epoch = 1157, loss = 2.8667)
# Saving model (epoch = 1194, loss = 2.8661)
# Saving model (epoch = 1213, loss = 2.8526)
# Saving model (epoch = 1253, loss = 2.8502)
# Saving model (epoch = 1273, loss = 2.8235)
# Saving model (epoch = 1300, loss = 2.8203)
# Saving model (epoch = 1302, loss = 2.8048)
# Saving model (epoch = 1342, loss = 2.7939)
# Saving model (epoch = 1368, loss = 2.7882)
# Saving model (epoch = 1400, loss = 2.7576)
# Saving model (epoch = 1417, loss = 2.7458)
# Saving model (epoch = 1466, loss = 2.7160)
# Saving model (epoch = 1554, loss = 2.6967)
# Saving model (epoch = 1636, loss = 2.6935)
# Saving model (epoch = 1646, loss = 2.6781)
# Saving model (epoch = 1672, loss = 2.6746)
# Saving model (epoch = 1725, loss = 2.6488)
# Saving model (epoch = 1879, loss = 2.6187)
# Saving model (epoch = 1968, loss = 2.6159)
# Saving model (epoch = 1983, loss = 2.6080)
# Saving model (epoch = 2097, loss = 2.6002)
# Saving model (epoch = 2110, loss = 2.5995)
# Saving model (epoch = 2131, loss = 2.5938)
# Saving model (epoch = 2140, loss = 2.5865)
# Saving model (epoch = 2152, loss = 2.5542)
# Saving model (epoch = 2224, loss = 2.5400)
# Saving model (epoch = 2279, loss = 2.5350)
# Saving model (epoch = 2343, loss = 2.5032)
# Saving model (epoch = 2368, loss = 2.4905)
# Saving model (epoch = 2530, loss = 2.4790)
# Saving model (epoch = 2639, loss = 2.4591)
# Saving model (epoch = 2702, loss = 2.4534)
# Finished training after 2903 epochs

# %%
plot_learning_curve(model_loss_record[1], title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
# Out:
# <All keys matched successfully>

# %%
prediction = test(tt_set, model, device)

# %%
prediction
# Out:
# array([-17.380896, -17.261932, -17.132187, -16.985163, -17.131554,
#        -17.571383, -17.63122 , -16.976818, -17.502485, -17.648829,
#        -17.57123 , -17.565199, -17.716177, -17.906666, -17.436007,
#        -17.505322, -17.53676 , -17.501225, -17.580408, -16.924412,
#        -18.66465 , -17.779757, -17.082443, -17.00916 , -17.380983],
#       dtype=float32)

# %%
labels = np.array([str(15*j) for j in range(25)])
#資料個數
dataLenth = 25
#資料
data = np.array(prediction)

angles = np.linspace(0, 2*np.pi, dataLenth, endpoint=False)
data = np.concatenate((data, [data[0]])) # 閉合 # #將資料結合起來
angles = np.concatenate((angles, [angles[0]])) # 閉合

fig = plt.figure()
ax = fig.add_subplot(121, polar=True)# polar引數！！代表畫圓形！！！！
#111代表總行數總列數位置
ax.plot(angles, data, 'b', linewidth=1, markersize=0)# 畫線四個引數為x,y,標記和顏色，閒的寬度
ax.fill(angles, data, facecolor='g', alpha=0)# 填充顏色和透明度
ax.set_thetagrids(angles * 180/np.pi, labels, fontproperties="SimHei")
#ax.set_title("H dB",fontsize = 80, fontproperties="SimHei")
ax.set_rlim(-40,-10)
ax.grid(True)
plt.show()
